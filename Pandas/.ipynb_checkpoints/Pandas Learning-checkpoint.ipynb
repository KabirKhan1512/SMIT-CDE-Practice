# %%
df = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9],], columns=["first", "second", "third"], index=["a","b","c"])
df
# Out:
#    first  second  third
# a      1       2      3
# b      4       5      6
# c      7       8      9

# %%
df.columns
# Out:
# Index(['first', 'second', 'third'], dtype='object')

# %%
a = df.columns.tolist()
a
# Out:
# ['first', 'second', 'third']

# %%
import numpy as np

# %%
a = np.random.randint(1,99,size=(50,2))
a
# Out:
# array([[78,  4],
#        [72,  9],
#        [80, 65],
#        [ 6,  5],
#        [30, 41],
#        [65, 12],
#        [10, 89],
#        [61, 69],
#        [37, 73],
#        [76,  5],
#        [27, 63],
#        [19, 83],
#        [37, 34],
#        [43, 49],
#        [88, 84],
#        [54, 28],
#        [ 3, 69],
#        [ 7, 64],
#        [ 8, 45],
#        [61, 93],
#        [15, 55],
#        [97, 88],
#        [69, 29],
#        [72, 39],
#        [37, 95],
#        [78, 33],
#        [60, 89],
#        [91, 78],
#        [73, 40],
#        [59, 60],
#        [74, 53],
#        [61, 89],
#        [ 6, 39],
#        [73, 95],
#        [67, 67],
#        [19, 16],
#        [50, 95],
#        [96, 16],
#        [12, 42],
#        [30, 76],
#        [64, 79],
#        [70, 70],
#        [13, 45],
#        [78, 38],
#        [10, 52],
#        [63, 26],
#        [79, 98],
#        [46, 71],
#        [22, 37],
#        [35, 95]], dtype=int32)

# %%
df = pd.DataFrame(a, columns=["first", "second"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   first   50 non-null     int32
#  1   second  50 non-null     int32
# dtypes: int32(2)
# memory usage: 532.0 bytes

# %%
df.describe()
# Out:
#            first    second
# count  50.000000  50.00000
# mean   49.620000  55.78000
# std    28.131535  28.11949
# min     3.000000   4.00000
# 25%    23.250000  37.25000
# 50%    59.500000  57.50000
# 75%    72.750000  78.75000
# max    97.000000  98.00000

# %%
df.shape
# Out:
# (50, 2)

# %%
df["first"].unique
# Out:
# <bound method Series.unique of 0     78
# 1     72
# 2     80
# 3      6
# 4     30
# 5     65
# 6     10
# 7     61
# 8     37
# 9     76
# 10    27
# 11    19
# 12    37
# 13    43
# 14    88
# 15    54
# 16     3
# 17     7
# 18     8
# 19    61
# 20    15
# 21    97
# 22    69
# 23    72
# 24    37
# 25    78
# 26    60
# 27    91
# 28    73
# 29    59
# 30    74
# 31    61
# 32     6
# 33    73
# 34    67
# 35    19
# 36    50
# 37    96
# 38    12
# 39    30
# 40    64
# 41    70
# 42    13
# 43    78
# 44    10
# 45    63
# 46    79
# 47    46
# 48    22
# 49    35
# Name: first, dtype: int32>

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of     first  second
# 0      78       4
# 1      72       9
# 2      80      65
# 3       6       5
# 4      30      41
# 5      65      12
# 6      10      89
# 7      61      69
# 8      37      73
# 9      76       5
# 10     27      63
# 11     19      83
# 12     37      34
# 13     43      49
# 14     88      84
# 15     54      28
# 16      3      69
# 17      7      64
# 18      8      45
# 19     61      93
# 20     15      55
# 21     97      88
# 22     69      29
# 23     72      39
# 24     37      95
# 25     78      33
# 26     60      89
# 27     91      78
# 28     73      40
# 29     59      60
# 30     74      53
# 31     61      89
# 32      6      39
# 33     73      95
# 34     67      67
# 35     19      16
# 36     50      95
# 37     96      16
# 38     12      42
# 39     30      76
# 40     64      79
# 41     70      70
# 42     13      45
# 43     78      38
# 44     10      52
# 45     63      26
# 46     79      98
# ...

# %%
coffee = pd.read_csv("coffee.csv")
coffee
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
# import pandas as pd
df1 = pd.read_csv("olympics.csv")
df1
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df1.sample(10)
# Out:
#             ID                                      Name Sex   Age  Height  \
# 953        535             Yevgeny Sergeyevich Abramenko   M  26.0   181.0
# 204598  102729                             Robert Rosser   M  28.0   178.0
# 97219    49208                                Hans Hfner   M  23.0     NaN
# 186143   93586                          Mark John Perrow   M  26.0   188.0
# 190735   95801                                Ivis Poleo   F  13.0   168.0
# 198600   99729  George Patten "Pat" Reiffenstein (-Carr)   M  21.0     NaN
# 51850    26649        Frederick Monroe "Fred" de Selding   M  20.0   175.0
# 260898  130549                           Angela Williams   F  19.0   175.0
# 193293   97034                             Gramen Prinov   M  24.0   186.0
# 130250   65551                        Lauri Viljo Kystil   M  30.0   169.0
#
#         Weight                 Team  NOC        Games  Year  Season  \
# 953       80.0              Belarus  BLR  2014 Winter  2014  Winter
# ...

# %%
df1.loc[5:,("Name", "NOC", "City")].sample(10)
# Out:
#                                   Name  NOC         City
# 103102   Barbara Jean Inkpen (-Lawton)  GBR  Mexico City
# 68808     Brigitte Fetzer (-Consuegra)  GDR       Moskva
# 36122         Nancy Carrillo de la Paz  CUB      Beijing
# 111195  Sigfrid Harald Alexander Julin  SWE       London
# 85939              Jaime Guerra Piedra  MEX      Atlanta
# 141823   Ronald Peter "Ronnie" Lombard  RSA    Melbourne
# 200526                      Hans Riedl  AUT  Los Angeles
# 61979                      Geir Einang  NOR      Calgary
# 150474          Liselotte Marti (-Znd)  SUI       Munich
# 63762                 Itzhak Englander  ISR  Mexico City

# %%
df1.loc[10]
# Out:
# ID                                               6
# Name                               Per Knut Aaland
# Sex                                              M
# Age                                           31.0
# Height                                       188.0
# Weight                                        75.0
# Team                                 United States
# NOC                                            USA
# Games                                  1992 Winter
# Year                                          1992
# Season                                      Winter
# City                                   Albertville
# Sport                         Cross Country Skiing
# Event     Cross Country Skiing Men's 10 kilometres
# Medal                                          NaN
# Name: 10, dtype: object

# %%
df1.loc[5:10]
# Out:
#     ID                      Name Sex   Age  Height  Weight           Team  \
# 5    5  Christine Jacoba Aaftink   F  21.0   185.0    82.0    Netherlands
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0    Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0    82.0    Netherlands
# 8    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0    Netherlands
# 9    5  Christine Jacoba Aaftink   F  27.0   185.0    82.0    Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0    75.0  United States
#
#     NOC        Games  Year  Season         City                 Sport  \
# 5   NED  1988 Winter  1988  Winter      Calgary         Speed Skating
# 6   NED  1992 Winter  1992  Winter  Albertville         Speed Skating
# 7   NED  1992 Winter  1992  Winter  Albertville         Speed Skating
# 8   NED  1994 Winter  1994  Winter  Lillehammer         Speed Skating
# 9   NED  1994 Winter  1994  Winter  Lillehammer         Speed Skating
# ...

# %%
df1.loc[5:10, "Name"]
# Out:
# 5     Christine Jacoba Aaftink
# 6     Christine Jacoba Aaftink
# 7     Christine Jacoba Aaftink
# 8     Christine Jacoba Aaftink
# 9     Christine Jacoba Aaftink
# 10             Per Knut Aaland
# Name: Name, dtype: object

# %%
df1.loc[5:10, ["Name","NOC"]]
# Out:
#                         Name  NOC
# 5   Christine Jacoba Aaftink  NED
# 6   Christine Jacoba Aaftink  NED
# 7   Christine Jacoba Aaftink  NED
# 8   Christine Jacoba Aaftink  NED
# 9   Christine Jacoba Aaftink  NED
# 10           Per Knut Aaland  USA

# %%
df1.iloc[:,[1,3]]
# Out:
#                             Name   Age
# 0                      A Dijiang  24.0
# 1                       A Lamusi  23.0
# 2            Gunnar Nielsen Aaby  24.0
# 3           Edgar Lindenau Aabye  34.0
# 4       Christine Jacoba Aaftink  21.0
# ...                          ...   ...
# 271111                Andrzej ya  29.0
# 271112                  Piotr ya  27.0
# 271113                  Piotr ya  27.0
# 271114        Tomasz Ireneusz ya  30.0
# 271115        Tomasz Ireneusz ya  34.0
#
# [271116 rows x 2 columns]

# %%
df1.at[3,"Age"]
# Out:
# np.float64(34.0)

# %%
df1.iat[3,6]
# Out:
# 'Denmark/Sweden'

# %%
df1[["Age","Name"]]
# Out:
#          Age                      Name
# 0       24.0                 A Dijiang
# 1       23.0                  A Lamusi
# 2       24.0       Gunnar Nielsen Aaby
# 3       34.0      Edgar Lindenau Aabye
# 4       21.0  Christine Jacoba Aaftink
# ...      ...                       ...
# 271111  29.0                Andrzej ya
# 271112  27.0                  Piotr ya
# 271113  27.0                  Piotr ya
# 271114  30.0        Tomasz Ireneusz ya
# 271115  34.0        Tomasz Ireneusz ya
#
# [271116 rows x 2 columns]

# %%
df1.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
df1[df1["Age"]<=11]
# Out:
#             ID                                             Name Sex   Age  \
# 43468    22411                       Magdalena Cecilia Colledge   F  11.0
# 73461    37333                  Carlos Bienvenido Front Barrera   M  11.0
# 79024    40129                                 Luigina Giavotti   F  11.0
# 94058    47618       Sonja Henie (-Topping, -Gardiner, -Onstad)   F  11.0
# 101378   51268                                   Beatrice Hutiu   F  11.0
# 102916   52070                                     Etsuko Inada   F  11.0
# 140650   70616                                       Liu Luyang   F  11.0
# 142882   71691                               Dimitrios Loundras   M  10.0
# 152798   76675                                Marcelle Matthews   F  11.0
# 237141  118925  Megan Olwen Devenish Taylor (-Mandeville-Ellis)   F  11.0
# 252230  126307                                     Liana Vicens   F  11.0
# 252231  126307                                     Liana Vicens   F  11.0
# ...

# %%
df1.sort_values(["Age","ID"])
# Out:
#             ID                                        Name Sex   Age  Height  \
# 142882   71691                          Dimitrios Loundras   M  10.0     NaN
# 43468    22411                  Magdalena Cecilia Colledge   F  11.0   152.0
# 73461    37333             Carlos Bienvenido Front Barrera   M  11.0     NaN
# 79024    40129                            Luigina Giavotti   F  11.0     NaN
# 94058    47618  Sonja Henie (-Topping, -Gardiner, -Onstad)   F  11.0   155.0
# ...        ...                                         ...  ..   ...     ...
# 270679  135368                           Antonio A. Zucchi   M   NaN     NaN
# 270774  135416                                   Star Zulu   M   NaN     NaN
# 270793  135426                                Max Zumstein   M   NaN     NaN
# 270804  135434                          Edmundo Ziga Erraz   M   NaN   180.0
# 270805  135435                                  Faelo Ziga   M   NaN     NaN
#
# ...

# %%
df1.loc[df1["Age"]<=15, ["Name","Age", "City","Sport","Year"]]
# Out:
#                                              Name   Age       City  \
# 265                     Giordano Giulio Abbondati  15.0  Innsbruck
# 295     Reem Wa'il Abdalazem Abdalazem El-Bossaty  15.0    Beijing
# 296     Reem Wa'il Abdalazem Abdalazem El-Bossaty  15.0    Beijing
# 517         Fatima Abdul Majeed Hameed Al-Kirashi  14.0     Sydney
# 600        Shaza Yahia Nazih Abdulrahman El-Sayed  15.0    Beijing
# ...                                           ...   ...        ...
# 269658                             Miriam Ziegler  15.0  Vancouver
# 269824                             Eileen Zillmer  15.0   Grenoble
# 270856                      Bernadette Zurbriggen  15.0    Sapporo
# 270857                      Bernadette Zurbriggen  15.0    Sapporo
# 270858                      Bernadette Zurbriggen  15.0    Sapporo
#
#                         Sport  Year
# 265            Figure Skating  1964
# 295     Synchronized Swimming  2008
# 296     Synchronized Swimming  2008
# ...

# %%
df1[(df1["Age"]<=13) & (df1["Year"]>1999)][["Name","Year","NOC"]]
# Out:
#                                                  Name  Year  NOC
# 7500    Tojohanitra Tokin'aina Andriamanjatoarimanana  2004  MAD
# 38322                          Wing Suet "Sandy" Chan  2000  HKG
# 49377                                 Ana Iulia Dascl  2016  ROU
# 55356                           Dwayne Benjamin Didon  2008  SEY
# 66899                                Fariha Fathimath  2000  MDV
# 85840                  Antoinette Joyce Guedia Mouafo  2008  CMR
# 101312                          Aminath Rouya Hussain  2004  MDV
# 126220                            Adzo Rebecca Kpossi  2012  TOG
# 197756                                     Rubab Raza  2004  PAK
# 205723                    Yekaterina Olegovna Rudenko  2008  KAZ
# 221023                                  Gaurika Singh  2016  NEP
# 265800                            Yip Tsz Wa "Yvonne"  2004  HKG

# %%
df1[(df1["Name"].str.contains("Khan")) & (df1["NOC"].str.contains("PAK"))]
# Out:
#             ID                       Name Sex   Age  Height  Weight      Team  \
# 4754      2716          Mudassar Ali Khan   M  24.0   178.0    75.0  Pakistan
# 32351    16626      Hamidullah Khan Burki   M  27.0     NaN     NaN  Pakistan
# 112247   56851            Kalimullah Khan   M  26.0   175.0    75.0  Pakistan
# 116833   59130         Abdul Ghafoor Khan   M   NaN     NaN     NaN  Pakistan
# 116836   59132          Abdul Haseem Khan   M  25.0     NaN     NaN  Pakistan
# 116837   59133          Abdul Qayyum Khan   M   NaN     NaN     NaN  Pakistan
# 116838   59134          Abdul Waheed Khan   M  23.0   174.0    60.0  Pakistan
# 116839   59135              Abdullah Khan   M   NaN     NaN     NaN  Pakistan
# 116840   59135              Abdullah Khan   M   NaN     NaN     NaN  Pakistan
# 116843   59137             Ahmed Ali Khan   M  23.0   185.0    75.0  Pakistan
# 116847   59141                  Anar Khan   M  25.0   176.0    70.0  Pakistan
# ...

# %%
df1[df1["Name"].str.contains("Khan|Kabir")]
# Out:
#             ID                       Name Sex   Age  Height  Weight  \
# 207593  104170  Sagdat Kabirovich Sadykov   M  27.0   175.0    73.0
# 207594  104170  Sagdat Kabirovich Sadykov   M  31.0   175.0    73.0
#
#               Team  NOC        Games  Year  Season    City Sport  \
# 207593  Kyrgyzstan  KGZ  2000 Summer  2000  Summer  Sydney  Judo
# 207594  Kazakhstan  KAZ  2004 Summer  2004  Summer  Athina  Judo
#
#                          Event Medal
# 207593  Judo Men's Lightweight   NaN
# 207594  Judo Men's Lightweight   NaN

# %%
df1[df1["NOC"].isin(["USA", "GBR"])]
# Out:
#             ID                        Name Sex   Age  Height  Weight  \
# 10           6             Per Knut Aaland   M  31.0   188.0    75.0
# 11           6             Per Knut Aaland   M  31.0   188.0    75.0
# 12           6             Per Knut Aaland   M  31.0   188.0    75.0
# 13           6             Per Knut Aaland   M  31.0   188.0    75.0
# 14           6             Per Knut Aaland   M  33.0   188.0    75.0
# ...        ...                         ...  ..   ...     ...     ...
# 270850  135458                    Rami Zur   M  27.0   175.0    77.0
# 270851  135458                    Rami Zur   M  31.0   175.0    77.0
# 270852  135458                    Rami Zur   M  31.0   175.0    77.0
# 271044  135543  Victor Andrew "Vic" Zwolak   M  25.0   175.0    64.0
# 271107  135566  James Francis "Jim" Zylker   M  21.0   175.0    75.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 10      United States  USA  1992 Winter  1992  Winter  Albertville
# ...

# %%
df1[df1["Name"].str.startswith("Akh")]
# Out:
#             ID                           Name Sex   Age  Height  Weight  \
# 2948      1642                  Akhat Akhirov   M  26.0     NaN     NaN
# 6484      3637               Akhmed Anarbayev   M  20.0   178.0    65.0
# 101292   51212                 Akhtar Hussain   M  21.0     NaN     NaN
# 101293   51212                 Akhtar Hussain   M  30.0     NaN     NaN
# 103879   52563                 Akhtarul Islam   M  25.0   185.0    85.0
# 128887   64880                    Akhil Kumar   M  23.0   165.0    54.0
# 128888   64880                    Akhil Kumar   M  27.0   165.0    54.0
# 197292   99051           Akhtar Rasool Kamboh   M  18.0   179.0    79.0
# 197293   99051           Akhtar Rasool Kamboh   M  22.0   179.0    79.0
# 226406  113792  Akhnaten A. "Akhi" Spencer-El   M  21.0   180.0    84.0
#
#                  Team  NOC        Games  Year  Season         City     Sport  \
# 2948       Kazakhstan  KAZ  1996 Summer  1996  Summer      Atlanta      Judo
# ...

# %%
df1.query('NOC == "USA"')
# Out:
#             ID                        Name Sex   Age  Height  Weight  \
# 10           6             Per Knut Aaland   M  31.0   188.0    75.0
# 11           6             Per Knut Aaland   M  31.0   188.0    75.0
# 12           6             Per Knut Aaland   M  31.0   188.0    75.0
# 13           6             Per Knut Aaland   M  31.0   188.0    75.0
# 14           6             Per Knut Aaland   M  33.0   188.0    75.0
# ...        ...                         ...  ..   ...     ...     ...
# 270850  135458                    Rami Zur   M  27.0   175.0    77.0
# 270851  135458                    Rami Zur   M  31.0   175.0    77.0
# 270852  135458                    Rami Zur   M  31.0   175.0    77.0
# 271044  135543  Victor Andrew "Vic" Zwolak   M  25.0   175.0    64.0
# 271107  135566  James Francis "Jim" Zylker   M  21.0   175.0    75.0
#
#                  Team  NOC        Games  Year  Season         City  \
# 10      United States  USA  1992 Winter  1992  Winter  Albertville
# ...

# %%
ndf = df1.copy()

# %%
ndf
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
ndf["Period"] = 10

# %%
ndf
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df1
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
import pandas as pd

# %%
df1.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df1.drop(0)
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 1                China  CHN  2012 Summer  2012  Summer          London
# ...

# %%
df1.drop(columns=["ID"])
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# 0                      A Dijiang   M  24.0   180.0    80.0           China
# 1                       A Lamusi   M  23.0   170.0    60.0           China
# 2            Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3           Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 271111                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 271112                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271113                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271114        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 271115        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
# ...

# %%
df1.drop(columns="NOC")
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team        Games  Year  Season            City  \
# 0                China  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df1
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df1.drop(columns="NOC", inplace=True)

# %%
df1
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team        Games  Year  Season            City  \
# 0                China  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df1['calculation']= df1["Age"] * df1["Height"]
df1.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#          Games  Year  Season       City          Sport  \
# 0  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  2012 Summer  2012  Summer     London           Judo
# 2  1920 Summer  1920  Summer  Antwerpen       Football
# 3  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal  calculation
# 0       Basketball Men's Basketball   NaN       4320.0
# 1      Judo Men's Extra-Lightweight   NaN       3910.0
# ...

# %%
df1
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team        Games  Year  Season            City  \
# 0                China  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df1.rename(columns={"Team":"Country"}, inplace=True)

# %%
df1
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Country        Games  Year  Season            City  \
# 0                China  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df1 = pd.read_csv("olympics.csv")
df1.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df1.to_csv("save_olympics.csv", index=False)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
df = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv")
df.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
df.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg   died_date
# 0               Gironde          FRA  France        NaN        NaN  1960-10-02
# 1              Yvelines          FRA  France      183.0       76.0         NaN
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0  1994-07-17
# 3                 Paris          FRA  France      168.0       64.0  1978-03-20
# 4               England          GBR  France        NaN        NaN  1930-07-25

# %%
df["born_year"] = pd.to_datetime(df["born_date"], errors="coerce")

# %%
df.head()
# Out:
#    athlete_id                   name   born_date    born_city  \
# 0           1  Jean-François Blanchy  1886-12-12     Bordeaux
# 1           2         Arnaud Boetsch  1969-04-01       Meulan
# 2           3           Jean Borotra  1898-08-13     Biarritz
# 3           4        Jacques Brugnon  1895-05-11  Paris VIIIe
# 4           5           Albert Canet  1878-04-17   Wandsworth
#
#             born_region born_country     NOC  height_cm  weight_kg  \
# 0               Gironde          FRA  France        NaN        NaN
# 1              Yvelines          FRA  France      183.0       76.0
# 2  Pyrénées-Atlantiques          FRA  France      183.0       76.0
# 3                 Paris          FRA  France      168.0       64.0
# 4               England          GBR  France        NaN        NaN
#
#     died_date  born_year
# 0  1960-10-02 1886-12-12
# 1         NaN 1969-04-01
# 2  1994-07-17 1898-08-13
# 3  1978-03-20 1895-05-11
# 4  1930-07-25 1878-04-17

# %%
df["born_year"] = df["born_year"].dt.year
df
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
df.isna().sum()
# Out:
# athlete_id           0
# name                 0
# born_date         1807
# born_city        34592
# born_region      34592
# born_country     34592
# NOC                  1
# height_cm        38849
# weight_kg        43430
# died_date       111560
# born_year         1807
# dtype: int64

# %%
df["weight_kg"].fillna(100)
# Out:
# 0         100.0
# 1          76.0
# 2          76.0
# 3          64.0
# 4         100.0
#           ...
# 145495     61.0
# 145496     65.0
# 145497     55.0
# 145498    100.0
# 145499    100.0
# Name: weight_kg, Length: 145500, dtype: float64

# %%
df["weight_kg"] = df["weight_kg"].fillna(df["weight_kg"].mean())
df["weight_kg"].head()
# Out:
# 0    71.890996
# 1    76.000000
# 2    76.000000
# 3    64.000000
# 4    71.890996
# Name: weight_kg, dtype: float64

# %%
df
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("bios.csv")
df
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
df["height_cm"].isna().sum()
# Out:
# np.int64(38849)

# %%
df["height_cm"].interpolate()
# Out:
# 0           NaN
# 1         183.0
# 2         183.0
# 3         168.0
# 4         174.5
#           ...
# 145495    167.0
# 145496    168.0
# 145497    163.0
# 145498    166.0
# 145499    166.0
# Name: height_cm, Length: 145500, dtype: float64

# %%
df.dropna().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10794 entries, 2 to 141190
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   athlete_id    10794 non-null  int64
#  1   name          10794 non-null  object
#  2   born_date     10794 non-null  object
#  3   born_city     10794 non-null  object
#  4   born_region   10794 non-null  object
#  5   born_country  10794 non-null  object
#  6   NOC           10794 non-null  object
#  7   height_cm     10794 non-null  float64
#  8   weight_kg     10794 non-null  float64
#  9   died_date     10794 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 927.6+ KB

# %%
df.dropna(subset=["died_date"])
# Out:
#         athlete_id                   name   born_date           born_city  \
# 0                1  Jean-François Blanchy  1886-12-12            Bordeaux
# 2                3           Jean Borotra  1898-08-13            Biarritz
# 3                4        Jacques Brugnon  1895-05-11         Paris VIIIe
# 4                5           Albert Canet  1878-04-17          Wandsworth
# 7                8           Henri Cochet  1901-12-14        Villeurbanne
# ...            ...                    ...         ...                 ...
# 145435      149158      Patrick Gasienica  1998-11-28             McHenry
# 145492      149219  Carlos García-Ordóñez  1927-04-24  La Habana (Havana)
# 145494      149221          George Wright  1890-07-21             Toronto
# 145498      149225         André Foussard  1899-05-19               Niort
# 145499      149814          Bill Phillips  1913-07-15        Dulwich Hill
#
#                  born_region born_country            NOC  height_cm  \
# ...

# %%
df[df["height_cm"].notna()]
# Out:
#         athlete_id                 name   born_date        born_city  \
# 1                2       Arnaud Boetsch  1969-04-01           Meulan
# 2                3         Jean Borotra  1898-08-13         Biarritz
# 3                4      Jacques Brugnon  1895-05-11      Paris VIIIe
# 5                6    Nicolas Chatelain  1970-01-13           Amiens
# 6                7        Patrick Chila  1969-11-27      Ris-Orangis
# ...            ...                  ...         ...              ...
# 145494      149221        George Wright  1890-07-21          Toronto
# 145495      149222    Polina Luchnikova  2002-01-30            Serov
# 145496      149223  Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224      Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225       André Foussard  1899-05-19            Niort
#
#                  born_region born_country     NOC  height_cm  weight_kg  \
# ...

# %%
df[df["born_country"]=="JPN"]["height_cm"].mean()
# Out:
# np.float64(169.83365384615385)

# %%
df.groupby(["born_country"])["height_cm"].mean().sort_values(ascending=False).tail(10)
# Out:
# born_country
# MDV          160.400000
# LES          160.166667
# RWA          160.166667
# TLS          159.666667
# FLI                 NaN
# Luppe               NaN
# Munich              NaN
# NFI                 NaN
# SEY                 NaN
# Spreewald           NaN
# Name: height_cm, dtype: float64

# %%
df["rank_weight"] = df["weight_kg"].rank()

# %%
df[["name", "weight_kg", "rank_weight"]].sort_values(by=["rank_weight"])
# Out:
#                          name  weight_kg  rank_weight
# 28762          Choi Myong-Hui       25.0          1.0
# 90795           Kana Yamawaki       28.0          3.0
# 28712            Anita Jokiel       28.0          3.0
# 114713               Wang Xin       28.0          3.0
# 126937             Léia Silva       30.0          8.0
# ...                       ...        ...          ...
# 145492  Carlos García-Ordóñez        NaN          NaN
# 145493     Landysh Falyakhova        NaN          NaN
# 145494          George Wright        NaN          NaN
# 145498         André Foussard        NaN          NaN
# 145499          Bill Phillips        NaN          NaN
#
# [145500 rows x 3 columns]

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
import pandas as pd

# %% [markdown]
# ### bfill & Ffill

# %%
df = pd.read_csv("olympics.csv")
df.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
df.ffill()
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0   170.0    60.0
# 3            4      Edgar Lindenau Aabye   M  34.0   170.0    60.0
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.bfill()
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0   185.0    82.0
# 3            4      Edgar Lindenau Aabye   M  34.0   185.0    82.0
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %% [markdown]
# ### Interpolate

# %% [markdown]
# ### Groupby aggregation and mean

# %% [markdown]
# ### Mapping, apply, map

# %% [markdown]
# ### Pivot table and Crosstab

# %% [markdown]
# ### Multicolumn indexing

# %%
import numpy as np

# %%
a = np.random.randint(30,50, size=(6,6))
a
# Out:
# array([[30, 46, 33, 40, 45, 44],
#        [45, 48, 40, 39, 37, 41],
#        [44, 30, 42, 44, 45, 39],
#        [43, 41, 45, 47, 31, 35],
#        [44, 45, 40, 33, 42, 32],
#        [42, 36, 43, 33, 31, 41]], dtype=int32)

# %%
df = pd.DataFrame(a)
df
# Out:
#     0   1   2   3   4   5
# 0  30  46  33  40  45  44
# 1  45  48  40  39  37  41
# 2  44  30  42  44  45  39
# 3  43  41  45  47  31  35
# 4  44  45  40  33  42  32
# 5  42  36  43  33  31  41

# %%
m_ind = pd.MultiIndex.from_product([["kabir","jalal","junaid"], ["2020",'2021']])
m_ind
# Out:
# MultiIndex([( 'kabir', '2020'),
#             ( 'kabir', '2021'),
#             ( 'jalal', '2020'),
#             ( 'jalal', '2021'),
#             ('junaid', '2020'),
#             ('junaid', '2021')],
#            )

# %%
record = pd.DataFrame(a, index=m_ind)
record
# Out:
#               0   1   2   3   4   5
# kabir  2020  30  46  33  40  45  44
#        2021  45  48  40  39  37  41
# jalal  2020  44  30  42  44  45  39
#        2021  43  41  45  47  31  35
# junaid 2020  44  45  40  33  42  32
#        2021  42  36  43  33  31  41

# %% [markdown]
# ### Drop Duplicate

# %%
df.drop_duplicates()
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.drop_duplicates(subset="Name")
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 0            1                     A Dijiang   M  24.0   180.0    80.0
# 1            2                      A Lamusi   M  23.0   170.0    60.0
# 2            3           Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4          Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5      Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                           ...  ..   ...     ...     ...
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
# 271111  135569                    Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                      Piotr ya   M  27.0   176.0    59.0
# 271114  135571            Tomasz Ireneusz ya   M  30.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %%
df.drop_duplicates(subset=["Name","Team"])
# Out:
#             ID                          Name Sex   Age  Height  Weight  \
# 0            1                     A Dijiang   M  24.0   180.0    80.0
# 1            2                      A Lamusi   M  23.0   170.0    60.0
# 2            3           Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4          Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5      Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                           ...  ..   ...     ...     ...
# 271108  135567  Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271110  135568        Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
# 271111  135569                    Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                      Piotr ya   M  27.0   176.0    59.0
# 271114  135571            Tomasz Ireneusz ya   M  30.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# ...

# %% [markdown]
# ### String Operations
# some important str operations are as following:
# - str.contains('pattern')
# - str.startswith('pattern')
# - str.endswith('pattern')
# - str.replace('old', 'new')
# - str.isnumeric()

# %%
df[df["Games"].str.contains("Winter")]
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5  Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5  Christine Jacoba Aaftink   F  27.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                Team  NOC        Games  Year  Season            City  \
# 4       Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...

# %%
df[df["Name"].str.startswith("Kab")]
# Out:
#            ID               Name Sex   Age  Height  Weight      Team  NOC  \
# 116623  59006  Kabelo Kgosiemang   M  22.0   188.0    74.0  Botswana  BOT
# 131003  65944       Kabil Lahsen   M  24.0   170.0    67.0   Morocco  MAR
# 146586  73573      Kabil Mahmoud   M   NaN     NaN     NaN     Egypt  EGY
# 166056  83397     Kabange Mupopo   F  23.0   170.0    62.0    Zambia  ZAM
#
#               Games  Year  Season            City       Sport  \
# 116623  2008 Summer  2008  Summer         Beijing   Athletics
# 131003  1996 Summer  1996  Summer         Atlanta      Boxing
# 146586  1920 Summer  1920  Summer       Antwerpen  Gymnastics
# 166056  2016 Summer  2016  Summer  Rio de Janeiro   Athletics
#
#                                          Event Medal
# 116623               Athletics Men's High Jump   NaN
# 131003               Boxing Men's Welterweight   NaN
# 146586  Gymnastics Men's Individual All-Around   NaN
# 166056            Athletics Women's 400 metres   NaN

# %%
df[df["Name"].str.endswith("bir")]
# Out:
#             ID                  Name Sex   Age  Height  Weight      Team  NOC  \
# 48037    24758        Ali Reza Dabir   M  22.0   172.0    66.0      Iran  IRI
# 48038    24758        Ali Reza Dabir   M  26.0   172.0    66.0      Iran  IRI
# 87517    44371           Lvia Gyrbir   F  29.0   168.0    55.0   Hungary  HUN
# 104805   53048           Malik Jabir   M  23.0   168.0    74.0     Ghana  GHA
# 104806   53048           Malik Jabir   M  27.0   168.0    74.0     Ghana  GHA
# 204156  102493  Jaime Ros Puig-Subir   M  23.0     NaN     NaN     Spain  ESP
# 204157  102493  Jaime Ros Puig-Subir   M  23.0     NaN     NaN     Spain  ESP
# 204158  102493  Jaime Ros Puig-Subir   M  23.0     NaN     NaN     Spain  ESP
# 217171  109084        Ghulam Shabbir   M  26.0   175.0    63.0  Pakistan  PAK
# 221289  111204   Sandhu Singh Gurbir   M  25.0   176.0    82.0     India  IND
# 268177  134167          Mohamed Zbir   M  26.0   163.0    51.0   Morocco  MAR
# ...

# %%
df["Name"] = df["Name"].str.replace("Kahn", "Khan", regex=False)

# %%
df["Name"].str.isnumeric().sum()
# Out:
# np.int64(0)

# %%
df["Name"]
# Out:
# 0                        A Dijiang
# 1                         A Lamusi
# 2              Gunnar Nielsen Aaby
# 3             Edgar Lindenau Aabye
# 4         Christine Jacoba Aaftink
#                     ...
# 271111                  Andrzej ya
# 271112                    Piotr ya
# 271113                    Piotr ya
# 271114          Tomasz Ireneusz ya
# 271115          Tomasz Ireneusz ya
# Name: Name, Length: 271116, dtype: object
